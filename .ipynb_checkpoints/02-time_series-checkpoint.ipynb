# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt 
plt.rc("font", size=14)
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)

# %%
import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import pandas as pd
import statsmodels.api as sm
import matplotlib
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

# %% [markdown]
# # Crashes

# %%
data = pd.read_csv('data/00-crash_reporting_incidents.csv', low_memory = False)

# %%
data.head()
# Out:
#   Report Number Local Case Number               Agency Name  \
# 0   MCP3119001T         190047416  Montgomery County Police
# 1   MCP9428002D         190047394  Montgomery County Police
# 2   MCP27260043         190047395  Montgomery County Police
# 3   MCP91300088         190047384  Montgomery County Police
# 4   MCP1119007N         190047378  Montgomery County Police
#
#         ACRS Report Type         Crash Date/Time Hit/Run        Route Type  \
# 0  Property Damage Crash  10/03/2019 11:30:00 AM      No            County
# 1  Property Damage Crash  10/03/2019 09:50:00 AM      No            County
# 2  Property Damage Crash  10/03/2019 09:28:00 AM     Yes            County
# 3  Property Damage Crash  10/03/2019 09:03:00 AM     Yes        US (State)
# 4  Property Damage Crash  10/03/2019 08:06:00 AM      No  Maryland (State)
#
#    Mile Point Mile Point Direction Lane Direction  ...  Fixed Oject Struck  \
# 0        0.94                North          North  ...                 NaN
# 1        1.92                North          South  ...                 NaN
# 2        0.78                 East           West  ...                 NaN
# 3        2.72                North          South  ...                CURB
# 4        4.81                North          South  ...                 NaN
#
#                Junction      Intersection Type Intersection Area  \
# 0                   NaN                    NaN               NaN
# 1                   NaN                    NaN               NaN
# 2                   NaN                    NaN               NaN
# 3      NON INTERSECTION                    NaN               NaN
# 4  INTERSECTION RELATED  FOUR-WAY INTERSECTION               NaN
#
#    Road Alignment Road Condition  \
# 0        STRAIGHT     NO DEFECTS
# 1        STRAIGHT     NO DEFECTS
# 2        STRAIGHT     NO DEFECTS
# 3        STRAIGHT     NO DEFECTS
# 4        STRAIGHT     NO DEFECTS
#
#                                       Road Division   Latitude  Longitude  \
# 0         TWO-WAY, DIVIDED, POSITIVE MEDIAN BARRIER  39.172548 -77.203174
# 1  TWO-WAY, DIVIDED, UNPROTECTED PAINTED MIN 4 FEET  39.253445 -77.275482
# 2                              TWO-WAY, NOT DIVIDED  39.053780 -77.099195
# 3         TWO-WAY, DIVIDED, POSITIVE MEDIAN BARRIER  39.019415 -77.013685
# 4  TWO-WAY, DIVIDED, UNPROTECTED PAINTED MIN 4 FEET  39.059683 -77.051695
#
#                      Location
# 0   (39.17254783, -77.203174)
# 1   (39.253445, -77.27548167)
# 2  (39.05378023, -77.0991953)
# 3     (39.019415, -77.013685)
# 4   (39.05968333, -77.051695)
#
# [5 rows x 44 columns]

# %%
data.columns.tolist()
# Out:
# ['Report Number',
#  'Local Case Number',
#  'Agency Name',
#  'ACRS Report Type',
#  'Crash Date/Time',
#  'Hit/Run',
#  'Route Type',
#  'Mile Point',
#  'Mile Point Direction',
#  'Lane Direction',
#  'Lane Number',
#  'Lane Type',
#  'Number of Lanes',
#  'Direction',
#  'Distance',
#  'Distance Unit',
#  'Road Grade',
#  'NonTraffic',
#  'Road Name',
#  'Cross-Street Type',
#  'Cross-Street Name',
#  'Off-Road Description',
#  'Municipality',
#  'Related Non-Motorist',
#  'At Fault',
#  'Collision Type',
#  'Weather',
#  'Surface Condition',
#  'Light',
#  'Traffic Control',
#  'Driver Substance Abuse',
#  'Non-Motorist Substance Abuse',
#  'First Harmful Event',
#  'Second Harmful Event',
#  'Fixed Oject Struck',
#  'Junction',
#  'Intersection Type',
#  'Intersection Area',
#  'Road Alignment',
#  'Road Condition',
#  'Road Division',
#  'Latitude',
#  'Longitude',
#  'Location']

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_stacked_bar(data, series_labels, category_labels=None, 
                     show_values=False, value_format="{}", y_label=None, 
                     colors=None, grid=True, reverse=False):
    """Plots a stacked bar chart with the data and labels provided.

    Keyword arguments:
    data            -- 2-dimensional numpy array or nested list
                       containing data for each series in rows
    series_labels   -- list of series labels (these appear in
                       the legend)
    category_labels -- list of category labels (these appear
                       on the x-axis)
    show_values     -- If True then numeric value labels will 
                       be shown on each bar
    value_format    -- Format string for numeric value labels
                       (default is "{}")
    y_label         -- Label for y-axis (str)
    colors          -- List of color labels
    grid            -- If True display grid
    reverse         -- If True reverse the order that the
                       series are displayed (left-to-right
                       or right-to-left)
    """

    ny = len(data[0])
    ind = list(range(ny))

    axes = []
    cum_size = np.zeros(ny)

    data = np.array(data)

    if reverse:
        data = np.flip(data, axis=1)
        category_labels = reversed(category_labels)

    for i, row_data in enumerate(data):
        axes.append(plt.bar(ind, row_data, bottom=cum_size, 
                            label=series_labels[i], color=colors[i]))
        cum_size += row_data

    if category_labels:
        plt.xticks(ind, category_labels)

    if y_label:
        plt.ylabel(y_label)

    plt.legend()

    if grid:
        plt.grid()

    if show_values:
        for axis in axes:
            for bar in axis:
                w, h = bar.get_width(), bar.get_height()
                plt.text(bar.get_x() + w/2, bar.get_y() + h/2, 
                         value_format.format(h), ha="center", 
                         va="center")

# %%
sns.barplot(x=data.groupby('Race')['Search Conducted'].value_counts().index, y=df.reputation.value_counts())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-db95c845ba1f> in <module>
# ----> 1 sns.barplot(x=data.groupby('Race')['Search Conducted'].value_counts().index, y=df.reputation.value_counts())
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7630         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    7631                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 7632                        observed=observed, **kwargs)
#    7633
#    7634     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2108         raise TypeError('invalid type: {}'.format(obj))
#    2109
# -> 2110     return klass(obj, by, **kwds)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     358                                                     sort=sort,
#     359                                                     observed=observed,
# --> 360                                                     mutated=self.mutated)
#     361
#     362         self.obj = obj
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     576                 in_axis, name, level, gpr = False, None, gpr, None
#     577             else:
# --> 578                 raise KeyError(gpr)
#     579         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     580             # Add key to exclusions
#
# KeyError: 'Race'

# %%
plt.figure(figsize=(16, 10))

series_labels = ['Series 1', 'Series 2']

data = [
    [0.965905, 0.914886, 0.913222, 0.956427, 0.963355,0.943589 ],
    [0.034095, 0.085114, 0.086778, 0.043573, 0.036645, 0.056411]
]

category_labels = ['Cat A', 'Cat B', 'Cat C', 'Cat D', 'Cat E', 'Cat F']

plot_stacked_bar(
    data, 
    series_labels, 
    category_labels=category_labels, 
    show_values=True, 
    value_format="{:.1f}",
    colors=['tab:orange', 'tab:green'],
    y_label="Quantity (units)"
)

plt.savefig('bar.png')
plt.show()

# %%
data.groupby('Race')['Search Conducted'].value_counts(normalize = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-4a4cd656d902> in <module>
# ----> 1 data.groupby('Race')['Search Conducted'].value_counts(normalize = True)
#
# AttributeError: 'list' object has no attribute 'groupby'

# %% [markdown]
# # Creating a time stamp and breaking it down

# %%
data = data.rename(columns={"Crash Date/Time" : "Date"})
data['Date'] = pd.to_datetime(data['Date'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-4d6a4902e86b> in <module>
# ----> 1 data = data.rename(columns={"Crash Date/Time" : "Date"})
#       2 data['Date'] = pd.to_datetime(data['Date'])
#
# AttributeError: 'list' object has no attribute 'rename'

# %%
# creating new empty columns to fill with time_stamp information
data['full_date'] = ''
data['year'] = ''
data['month'] = ''
data['day'] = ''
data['season'] = ''
data['workday'] = ''
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-11d3e4f99589> in <module>
#       1 # creating new empty columns to fill with time_stamp information
# ----> 2 data['full_date'] = ''
#       3 data['year'] = ''
#       4 data['month'] = ''
#       5 data['day'] = ''
#
# TypeError: list indices must be integers or slices, not str

# %%
data.full_date = data.Date.dt.date
data.year = data.Date.dt.year
data.month = data.Date.dt.month
data.day = data.Date.dt.day
data.workday = data.Date.dt.dayofweek
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-579cfff8b089> in <module>
# ----> 1 data.full_date = data.Date.dt.date
#       2 data.year = data.Date.dt.year
#       3 data.month = data.Date.dt.month
#       4 data.day = data.Date.dt.day
#       5 data.workday = data.Date.dt.dayofweek
#
# AttributeError: 'list' object has no attribute 'Date'

# %%
df_2015 = data.loc[data['year'] == 2015]
df_2016 = data.loc[data['year'] == 2016]
df_2017 = data.loc[data['year'] == 2017]
df_2018 = data.loc[data['year'] == 2018]
df_2019 = data.loc[data['year'] == 2019]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-692a070e0e6e> in <module>
# ----> 1 df_2015 = data.loc[data['year'] == 2015]
#       2 df_2016 = data.loc[data['year'] == 2016]
#       3 df_2017 = data.loc[data['year'] == 2017]
#       4 df_2018 = data.loc[data['year'] == 2018]
#       5 df_2019 = data.loc[data['year'] == 2019]
#
# AttributeError: 'list' object has no attribute 'loc'

# %%
#2015
value_counts = df_2015['month'].value_counts(dropna=True, sort=True)
df_2015 = pd.DataFrame(value_counts)
df_2015 = df_2015.reset_index()
df_2015.columns = ['unique_values', 'counts'] # change column names
df_2015 = df_2015.sort_values(by=['unique_values'])

#2016
value_counts = df_2016['month'].value_counts(dropna=True, sort=True)
df_2016 = pd.DataFrame(value_counts)
df_2016 = df_2016.reset_index()
df_2016.columns = ['unique_values', 'counts'] # change column names
df_2016 = df_2016.sort_values(by=['unique_values'])

#2017
value_counts = df_2017['month'].value_counts(dropna=True, sort=True)
df_2017 = pd.DataFrame(value_counts)
df_2017 = df_2017.reset_index()
df_2017.columns = ['unique_values', 'counts'] # change column names
df_2017 = df_2017.sort_values(by=['unique_values'])

#2018
value_counts = df_2018['month'].value_counts(dropna=True, sort=True)
df_2018 = pd.DataFrame(value_counts)
df_2018 = df_2018.reset_index()
df_2018.columns = ['unique_values', 'counts'] # change column names
df_2018 = df_2018.sort_values(by=['unique_values'])

#2019
value_counts = df_2019['month'].value_counts(dropna=True, sort=True)
df_2019 = pd.DataFrame(value_counts)
df_2019 = df_2019.reset_index()
df_2019.columns = ['unique_values', 'counts'] # change column names
df_2019 = df_2019.sort_values(by=['unique_values'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-d1d99046e756> in <module>
#       1 #2015
# ----> 2 value_counts = df_2015['month'].value_counts(dropna=True, sort=True)
#       3 df_2015 = pd.DataFrame(value_counts)
#       4 df_2015 = df_2015.reset_index()
#       5 df_2015.columns = ['unique_values', 'counts'] # change column names
#
# NameError: name 'df_2015' is not defined

# %%
plt.figure(figsize=(20,8))

p4 = plt.plot('unique_values', 'counts', data=df_2016, color = 'blue', label = '2016')
p5 = plt.plot('unique_values', 'counts', data=df_2017, color = 'magenta', label = '2017')
p6 = plt.plot('unique_values', 'counts', data=df_2018, color = 'orange', label = '2018')

plt.title('Crashed per Month and Year')
plt.xlabel('Date')
plt.ylabel('Values')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-c2446543526d> in <module>
#       1 plt.figure(figsize=(20,8))
#       2
# ----> 3 p4 = plt.plot('unique_values', 'counts', data=df_2016, color = 'blue', label = '2016')
#       4 p5 = plt.plot('unique_values', 'counts', data=df_2017, color = 'magenta', label = '2017')
#       5 p6 = plt.plot('unique_values', 'counts', data=df_2018, color = 'orange', label = '2018')
#
# NameError: name 'df_2016' is not defined

# %% [markdown]
# # Traffic Violations

# %%
data = pd.read_csv('data/Traffic_Violations (4).csv', low_memory = False)

# %%
data.head()
# Out:
#                                   SeqID Date Of Stop Time Of Stop Agency  \
# 0  02ccadf1-7ebd-48d8-a793-913e3198f52a   07/30/2019     22:15:00    MCP
# 1  3b060228-d664-4480-9314-6188ee8ac891   07/07/2019     22:54:00    MCP
# 2  d4dd55c0-adb0-434e-b5d9-d8346b0a4080   07/10/2019     16:00:00    MCP
# 3  abd509c6-edb3-4818-b90a-477cf92755e6   08/15/2019     22:42:00    MCP
# 4  021d5a2d-7989-4b52-a983-7f6e462fc123   04/15/2019     05:49:00    MCP
#
#                   SubAgency  \
# 0    2nd District, Bethesda
# 1     4th District, Wheaton
# 2   1st District, Rockville
# 3    2nd District, Bethesda
# 4  5th District, Germantown
#
#                                          Description  \
# 0         EXCEEDING THE POSTED SPEED LIMIT OF 35 MPH
# 1                       FAILURE TO STOP AT STOP SIGN
# 2                              HEADLIGHT INOPERATIVE
# 3  DRIVING VEH. W/O ADEQUATE REAR REG. PLATE ILLU...
# 4                  DRIVER CHANGING LANES WHEN UNSAFE
#
#                        Location   Latitude  Longitude Accident  ...  \
# 0    RIVER RD/ROYAL DOMINION DR  38.990102 -77.151645       No  ...
# 1     ENNALLS AVE @ GEORGIA AVE  39.040360 -77.051137       No  ...
# 2          SHADY GROVE @ TUPELO   0.000000   0.000000       No  ...
# 3        355 AT JONES BRIDGE RD  38.997645 -77.096600       No  ...
# 4  GERMANTOWN AT SHAKESPEARE RD   0.000000   0.000000       No  ...
#
#       Charge                 Article Contributed To Accident      Race Gender  \
# 0   21-801.1  Transportation Article                   False     ASIAN      F
# 1  21-707(a)  Transportation Article                   False  HISPANIC      M
# 2   11-393.9          Maryland Rules                   False  HISPANIC      M
# 3  22-204(f)  Transportation Article                   False     WHITE      F
# 4  21-309(b)  Transportation Article                   False     BLACK      F
#
#           Driver City Driver State DL State        Arrest Type  \
# 0             FAIRFAX           VA       VA   Q - Marked Laser
# 1       SILVER SPRING           MD       MD  A - Marked Patrol
# 2          ALEXANDRIA           VA       VA  A - Marked Patrol
# 3             POTOMAC           MD       MD  A - Marked Patrol
# 4  MONTGOMERY VILLAGE           MD       MD  A - Marked Patrol
#
#                       Geolocation
# 0  (38.9901016666667, -77.151645)
# 1   (39.04036, -77.0511366666667)
# 2                      (0.0, 0.0)
# 3           (38.997645, -77.0966)
# 4                      (0.0, 0.0)
#
# [5 rows x 43 columns]

# %%
data.Gender.value_counts()
# Out:
# M    174159
# F     80726
# U       355
# Name: Gender, dtype: int64

# %%
from datetime import datetime

# %%
data = data.rename(columns = {'Date Of Stop' : 'Date'})

# %%
# import datetime librarby to convert objects to datetimes
# from datetime import datetime

# changes 'time_stamp' to datetime
data['Date'] = pd.to_datetime(data['Date'])

# %%
# creating new empty columns to fill with time_stamp information
data['full_date'] = ''
data['year'] = ''
data['month'] = ''
data['day'] = ''
data['season'] = ''
data['workday'] = ''

# %%
data.full_date = data.Date.dt.date
data.year = data.Date.dt.year
data.month = data.Date.dt.month
data.day = data.Date.dt.day
data.workday = data.Date.dt.dayofweek

# %%
y12 = data.loc[data['year'] == 2012].month.value_counts(sort = False)
y13 = data.loc[data['year'] == 2013].month.value_counts(sort = False)
y14 = data.loc[data['year'] == 2014].month.value_counts(sort = False)
y15 = data.loc[data['year'] == 2015].month.value_counts(sort = False)
y16 = data.loc[data['year'] == 2016].month.value_counts(sort = False)
y17 = data.loc[data['year'] == 2017].month.value_counts(sort = False)
y18 = data.loc[data['year'] == 2018].month.value_counts(sort = False)
y19 = data.loc[data['year'] == 2019].month.value_counts(sort = False)

# %%
def plot_easy(y16, y17, y18):
    plt.figure(figsize = (20, 8))
    plt.plot(y16, label = '2016', color = 'blue')
    plt.plot(y17, label = '2017', color = 'magenta')
    plt.plot(y18, label = '2018', color = 'orange')
    plt.title('Traffic Violations per Month and Year')
    plt.xlabel('Date')
    plt.ylabel('Values')
    plt.legend()
    plt.show()
    
plot_easy(y16, y17, y18)

# %% [markdown]
# # Crashes vs Violations Compares

# %% [markdown]
# ## 2016

# %%
year_2016 = data.loc[data['year'] == 2016]
year_2017 = data.loc[data['year'] == 2017]
year_2018 = data.loc[data['year'] == 2018]

# %%
#2016
value_counts = year_2016['month'].value_counts(dropna=True, sort=True)
year_2016 = pd.DataFrame(value_counts)
year_2016 = year_2016.reset_index()
year_2016.columns = ['unique_values', 'counts'] # change column names
year_2016 = year_2016.sort_values(by=['unique_values'])

#2017
value_counts = year_2017['month'].value_counts(dropna=True, sort=True)
year_2017 = pd.DataFrame(value_counts)
year_2017 = year_2017.reset_index()
year_2017.columns = ['unique_values', 'counts'] # change column names
year_2017 = year_2017.sort_values(by=['unique_values'])

#2018
value_counts = year_2018['month'].value_counts(dropna=True, sort=True)
year_2018 = pd.DataFrame(value_counts)
year_2018 = year_2018.reset_index()
year_2018.columns = ['unique_values', 'counts'] # change column names
year_2018 = year_2018.sort_values(by=['unique_values'])

# %%
import pylab as plot
params = {'legend.fontsize': 20,
          'legend.handlelength': 2}
plot.rcParams.update(params)

# %%
plt.figure(figsize=(20,8))

crashes2016 = plt.plot('unique_values', 'counts', data=df_2016, color = 'red', label = 'Crashes')
traffic2016 = plt.plot('unique_values', 'counts', data=year_2016, color = 'blue', label = 'Traffic Violations')

plt.title('Traffic Violations vs Crashes for year 2016')
plt.xlabel('Date')
plt.ylabel('Values')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-b44c1ead5348> in <module>
#       1 plt.figure(figsize=(20,8))
#       2
# ----> 3 crashes2016 = plt.plot('unique_values', 'counts', data=df_2016, color = 'red', label = 'Crashes')
#       4 traffic2016 = plt.plot('unique_values', 'counts', data=year_2016, color = 'blue', label = 'Traffic Violations')
#       5
#
# NameError: name 'df_2016' is not defined

# %% [markdown]
# **We have plotted crashes vs traffic violations, however since our data is not normalized and very spread apart, we are getting issues**
# **We have to normalize our data the replot**

# %%
import pandas as pd
import matplotlib.pyplot as plt
tf = pd.read_csv('data/traffic_violations_month_year.csv')
crash = pd.read_csv('data/crashes_month_year.csv')

# %% [markdown]
# # 2016 - 2018

# %%
plt.figure(figsize=(20,8))

crashes_all= plt.plot('date', 'normalized', data=crash, color = 'red', label = 'Crashes')
tf_all= plt.plot('date', 'normalized', data=tf, color = 'blue', label = 'Traffic Violations')

plt.xticks(rotation=45)
plt.title('Traffic Violations vs Crashes - Normalized')
plt.xlabel('Date')
plt.ylabel('Values')
plt.legend()

# %%
crash_2016 = crash.loc[crash['year']==2016]
tf_2016 = tf.loc[tf['year'] == 2016]

crash_2017 = crash.loc[crash['year']==2017]
tf_2017 = tf.loc[tf['year'] == 2017]

crash_2018 = crash.loc[crash['year']==2018]
tf_2018 = tf.loc[tf['year'] == 2018]

# %% [markdown]
# # 2016

# %%
plt.figure(figsize=(20,8))

p2= plt.plot('date', 'normalized', data=crash_2016, color = 'red', label = 'Crashes')
p1= plt.plot('date', 'normalized', data=tf_2016, color = 'blue', label = 'Traffic Violations')


plt.xticks(rotation=45)
plt.title('Traffic Violations vs Crashes for 2016')
plt.xlabel('Date')
plt.ylabel('Values')
plt.legend()

# %% [markdown]
# # 2017

# %%
plt.figure(figsize=(20,8))

p2= plt.plot('date', 'normalized', data=crash_2017, color = 'red', label = 'Crashes')
p1= plt.plot('date', 'normalized', data=tf_2017, color = 'blue', label = 'Traffic Violations')


plt.xticks(rotation=45)
plt.title('Traffic Violations vs Crashes for 2017')
plt.xlabel('Date')
plt.ylabel('Values')
plt.legend()

# %% [markdown]
# # 2018

# %%
plt.figure(figsize=(20,8))

p2= plt.plot('date', 'normalized', data=crash_2018, color = 'red', label = 'Crashes')
p1= plt.plot('date', 'normalized', data=tf_2018, color = 'blue', label = 'Traffic Violations')

plt.xticks(rotation=45)
plt.title('Traffic Violations vs Crashes for 2018')
plt.xlabel('Date')
plt.ylabel('Values')
plt.legend()

# %%
data.head()
# Out:
#                                   SeqID       Date Time Of Stop Agency  \
# 0  02ccadf1-7ebd-48d8-a793-913e3198f52a 2019-07-30     22:15:00    MCP
# 1  3b060228-d664-4480-9314-6188ee8ac891 2019-07-07     22:54:00    MCP
# 2  d4dd55c0-adb0-434e-b5d9-d8346b0a4080 2019-07-10     16:00:00    MCP
# 3  abd509c6-edb3-4818-b90a-477cf92755e6 2019-08-15     22:42:00    MCP
# 4  021d5a2d-7989-4b52-a983-7f6e462fc123 2019-04-15     05:49:00    MCP
#
#                   SubAgency  \
# 0    2nd District, Bethesda
# 1     4th District, Wheaton
# 2   1st District, Rockville
# 3    2nd District, Bethesda
# 4  5th District, Germantown
#
#                                          Description  \
# 0         EXCEEDING THE POSTED SPEED LIMIT OF 35 MPH
# 1                       FAILURE TO STOP AT STOP SIGN
# 2                              HEADLIGHT INOPERATIVE
# 3  DRIVING VEH. W/O ADEQUATE REAR REG. PLATE ILLU...
# 4                  DRIVER CHANGING LANES WHEN UNSAFE
#
#                        Location   Latitude  Longitude Accident  ...  \
# 0    RIVER RD/ROYAL DOMINION DR  38.990102 -77.151645       No  ...
# 1     ENNALLS AVE @ GEORGIA AVE  39.040360 -77.051137       No  ...
# 2          SHADY GROVE @ TUPELO   0.000000   0.000000       No  ...
# 3        355 AT JONES BRIDGE RD  38.997645 -77.096600       No  ...
# 4  GERMANTOWN AT SHAKESPEARE RD   0.000000   0.000000       No  ...
#
#   Driver State DL State        Arrest Type                     Geolocation  \
# 0           VA       VA   Q - Marked Laser  (38.9901016666667, -77.151645)
# 1           MD       MD  A - Marked Patrol   (39.04036, -77.0511366666667)
# 2           VA       VA  A - Marked Patrol                      (0.0, 0.0)
# 3           MD       MD  A - Marked Patrol           (38.997645, -77.0966)
# 4           MD       MD  A - Marked Patrol                      (0.0, 0.0)
#
#     full_date    year month   day season workday
# 0  2019-07-30  2019.0   7.0  30.0            1.0
# 1  2019-07-07  2019.0   7.0   7.0            6.0
# 2  2019-07-10  2019.0   7.0  10.0            2.0
# 3  2019-08-15  2019.0   8.0  15.0            3.0
# 4  2019-04-15  2019.0   4.0  15.0            0.0
#
# [5 rows x 49 columns]

# %%
data.columns
# Out:
# Index(['SeqID', 'Date', 'Time Of Stop', 'Agency', 'SubAgency', 'Description',
#        'Location', 'Latitude', 'Longitude', 'Accident', 'Belts',
#        'Personal Injury', 'Property Damage', 'Fatal', 'Commercial License',
#        'HAZMAT', 'Commercial Vehicle', 'Alcohol', 'Work Zone',
#        'Search Conducted', 'Search Disposition', 'Search Outcome',
#        'Search Reason', 'Search Reason For Stop', 'Search Type',
#        'Search Arrest Reason', 'State', 'VehicleType', 'Year', 'Make', 'Model',
#        'Color', 'Violation Type', 'Charge', 'Article',
#        'Contributed To Accident', 'Race', 'Gender', 'Driver City',
#        'Driver State', 'DL State', 'Arrest Type', 'Geolocation', 'full_date',
#        'year', 'month', 'day', 'season', 'workday'],
#       dtype='object')

# %%
data.groupby('year')['month'].value_counts()
# Out:
# year    month
# 2012.0  5.0       7396
#         11.0      5595
#         10.0      5479
#         7.0       5449
#         12.0      5379
#         9.0       5302
#         6.0       5192
#         8.0       4977
#         3.0       4880
#         1.0       4606
#         2.0       4381
#         4.0       4298
# 2013.0  1.0       4952
#         5.0       3726
#         8.0       3403
#         4.0       3378
#         9.0       3376
#         7.0       3303
#         3.0       3125
#         6.0       3095
#         10.0      3020
#         11.0      2661
#         2.0       1921
#         12.0      1561
# 2014.0  7.0       3293
#         3.0       2915
#         5.0       2852
#         10.0      2536
#         4.0       2314
#         8.0       1976
#                  ...
# 2017.0  11.0      1006
#         12.0       997
#         6.0        944
#         4.0        927
#         10.0       911
#         8.0        837
# 2018.0  1.0       1118
#         4.0       1074
#         8.0       1034
#         5.0       1018
#         6.0       1003
#         11.0       996
#         12.0       974
#         2.0        952
#         10.0       945
#         3.0        942
#         9.0        942
#         7.0        866
# 2019.0  9.0      15475
#         11.0     13588
#         10.0     12671
#         8.0      11722
#         7.0       4741
#         5.0       2556
#         6.0       2118
#         4.0       1506
#         3.0       1299
#         2.0        773
#         1.0        745
#         12.0       209
# Name: month, Length: 96, dtype: int64
