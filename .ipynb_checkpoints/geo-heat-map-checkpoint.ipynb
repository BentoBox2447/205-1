# %%
#Import the necessary libraries
import pandas as pd
import gmplot
# For improved table display in the notebook
from IPython.display import display

raw_data = pd.read_csv('data/Traffic_Violations (2).csv', low_memory = False)

# Success! Display the first 5 rows of the dataset
display(raw_data.head(n=5))
# Out:
#                                   SeqID Date Of Stop Time Of Stop Agency  \
# 0  02ccadf1-7ebd-48d8-a793-913e3198f52a   07/30/2019     22:15:00    MCP
# 1  3b060228-d664-4480-9314-6188ee8ac891   07/07/2019     22:54:00    MCP
# 2  d4dd55c0-adb0-434e-b5d9-d8346b0a4080   07/10/2019     16:00:00    MCP
# 3  abd509c6-edb3-4818-b90a-477cf92755e6   08/15/2019     22:42:00    MCP
# 4  021d5a2d-7989-4b52-a983-7f6e462fc123   04/15/2019     05:49:00    MCP
#
#                   SubAgency  \
# 0    2nd District, Bethesda
# 1     4th District, Wheaton
# 2   1st District, Rockville
# 3    2nd District, Bethesda
# 4  5th District, Germantown
#
#                                          Description  \
# 0         EXCEEDING THE POSTED SPEED LIMIT OF 35 MPH
# 1                       FAILURE TO STOP AT STOP SIGN
# 2                              HEADLIGHT INOPERATIVE
# 3  DRIVING VEH. W/O ADEQUATE REAR REG. PLATE ILLU...
# 4                  DRIVER CHANGING LANES WHEN UNSAFE
#
#                        Location   Latitude  Longitude Accident  ...  \
# 0    RIVER RD/ROYAL DOMINION DR  38.990102 -77.151645       No  ...
# 1     ENNALLS AVE @ GEORGIA AVE  39.040360 -77.051137       No  ...
# 2          SHADY GROVE @ TUPELO   0.000000   0.000000       No  ...
# 3        355 AT JONES BRIDGE RD  38.997645 -77.096600       No  ...
# 4  GERMANTOWN AT SHAKESPEARE RD   0.000000   0.000000       No  ...
#
#       Charge                 Article Contributed To Accident      Race Gender  \
# 0   21-801.1  Transportation Article                   False     ASIAN      F
# 1  21-707(a)  Transportation Article                   False  HISPANIC      M
# 2   11-393.9          Maryland Rules                   False  HISPANIC      M
# 3  22-204(f)  Transportation Article                   False     WHITE      F
# 4  21-309(b)  Transportation Article                   False     BLACK      F
#
#           Driver City Driver State DL State        Arrest Type  \
# 0             FAIRFAX           VA       VA   Q - Marked Laser
# 1       SILVER SPRING           MD       MD  A - Marked Patrol
# 2          ALEXANDRIA           VA       VA  A - Marked Patrol
# 3             POTOMAC           MD       MD  A - Marked Patrol
# 4  MONTGOMERY VILLAGE           MD       MD  A - Marked Patrol
#
#                       Geolocation
# 0  (38.9901016666667, -77.151645)
# 1   (39.04036, -77.0511366666667)
# 2                      (0.0, 0.0)
# 3           (38.997645, -77.0966)
# 4                      (0.0, 0.0)
#
# [5 rows x 43 columns]

# %%
display(raw_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1605307 entries, 0 to 1605306
# Data columns (total 43 columns):
# SeqID                      1605307 non-null object
# Date Of Stop               1605307 non-null object
# Time Of Stop               1605307 non-null object
# Agency                     1605307 non-null object
# SubAgency                  1605307 non-null object
# Description                1605298 non-null object
# Location                   1605305 non-null object
# Latitude                   1605307 non-null float64
# Longitude                  1605307 non-null float64
# Accident                   1605307 non-null object
# Belts                      1605307 non-null object
# Personal Injury            1605307 non-null object
# Property Damage            1605307 non-null object
# Fatal                      1605307 non-null object
# Commercial License         1605307 non-null object
# HAZMAT                     1605307 non-null object
# Commercial Vehicle         1605307 non-null object
# Alcohol                    1605307 non-null object
# Work Zone                  1605307 non-null object
# Search Conducted           995580 non-null object
# Search Disposition         70124 non-null object
# Search Outcome             976413 non-null object
# Search Reason              70124 non-null object
# Search Reason For Stop     995409 non-null object
# Search Type                70116 non-null object
# Search Arrest Reason       47647 non-null object
# State                      1605248 non-null object
# VehicleType                1605307 non-null object
# Year                       1595531 non-null float64
# Make                       1605242 non-null object
# Model                      1605103 non-null object
# Color                      1586416 non-null object
# Violation Type             1605307 non-null object
# Charge                     1605307 non-null object
# Article                    1527460 non-null object
# Contributed To Accident    1605307 non-null bool
# Race                       1605307 non-null object
# Gender                     1605307 non-null object
# Driver City                1604918 non-null object
# Driver State               1605296 non-null object
# DL State                   1604378 non-null object
# Arrest Type                1605307 non-null object
# Geolocation                1605307 non-null object
# dtypes: bool(1), float64(3), object(39)
# memory usage: 515.9+ MB
# None

# %%
# Let's limit the dataset to the first 15,000 records for this example
data = raw_data.head(n=15000)

# Store our latitude and longitude
latitudes = data["Latitude"]
longitudes = data["Longitude"]

# Creating the location we would like to initialize the focus on. 
# Parameters: Lattitude, Longitude, Zoom
gmap = gmplot.GoogleMapPlotter(34.0522, -118.2437, 10)

# Overlay our datapoints onto the map
gmap.heatmap(latitudes, longitudes)

# Generate the heatmap into an HTML file
gmap.draw("my_heatmap.html")
