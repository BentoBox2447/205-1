# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # EDA on 3 datasets

# %% [markdown]
# # Crash Reporting Incidents Data

# %%
incidents = pd.read_csv('https://data.montgomerycountymd.gov/resource/bhju-22kf.csv')

# %%
incidents.head()
# Out:
#   report_number  local_case_number                agency_name  \
# 0    DD5631002X          190048542  Rockville Police Departme
# 1   MCP2722003D          190048511   Montgomery County Police
# 2   MCP137800SP          190048504   Montgomery County Police
# 3   MCP3114001K          190048507   Montgomery County Police
# 4   MCP2516002Y          190048480   Montgomery County Police
#
#         acrs_report_type          crash_date_time hit_run        route_type  \
# 0  Property Damage Crash  2019-10-09T20:30:00.000      No  Maryland (State)
# 1           Injury Crash  2019-10-09T16:18:00.000      No               NaN
# 2           Injury Crash  2019-10-09T15:48:00.000      No            County
# 3  Property Damage Crash  2019-10-09T15:37:00.000     Yes            County
# 4           Injury Crash  2019-10-09T13:20:00.000      No  Maryland (State)
#
#    mile_point mile_point_direction lane_direction  ...  fixed_oject_struck  \
# ...

# %% [markdown]
# # Crash Reporting Drivers Data

# %%
drivers = pd.read_csv('data/01_crash_reporting_drivers.csv')

# %%
drivers.head()
# Out:
#   Report Number Local Case Number                Agency Name  \
# 0    DD5631002X         190048542  Rockville Police Departme
# 1    DD5631002X         190048542  Rockville Police Departme
# 2   MCP2722003D         190048511   Montgomery County Police
# 3   MCP137800SP         190048504   Montgomery County Police
# 4   MCP137800SP         190048504   Montgomery County Police
#
#         ACRS Report Type         Crash Date/Time        Route Type  \
# 0  Property Damage Crash  10/09/2019 08:30:00 PM  Maryland (State)
# 1  Property Damage Crash  10/09/2019 08:30:00 PM  Maryland (State)
# 2           Injury Crash  10/09/2019 04:18:00 PM               NaN
# 3           Injury Crash  10/09/2019 03:48:00 PM            County
# 4           Injury Crash  10/09/2019 03:48:00 PM            County
#
#           Road Name Cross-Street Type Cross-Street Name  \
# 0  W MONTGOMERY AVE      Municipality        HURLEY AVE
# 1  W MONTGOMERY AVE      Municipality        HURLEY AVE
# ...

# %% [markdown]
# # Crash Reporting Non-Motorists Data

# %%
non_motorists = pd.read_csv('data/02_crash_reporting_non-motorists.csv')
non_motorists.head()
# Out:
#   Report Number  Local Case Number                Agency Name  \
# 0   MCP2722003D          190048511   Montgomery County Police
# 1   MCP3111001P          190048267   Montgomery County Police
# 2   MCP137800SJ          190048178   Montgomery County Police
# 3    DD56300026          190049187  Rockville Police Departme
# 4   MCP1575009K          190048063   Montgomery County Police
#
#         ACRS Report Type         Crash Date/Time        Route Type  \
# 0           Injury Crash  10/09/2019 04:18:00 PM               NaN
# 1  Property Damage Crash  10/08/2019 10:11:00 AM  Maryland (State)
# 2           Injury Crash  10/07/2019 06:51:00 PM            County
# 3  Property Damage Crash  10/07/2019 07:55:00 AM      Municipality
# 4           Injury Crash  10/07/2019 07:41:00 AM            County
#
#              Road Name Cross-Street Type   Cross-Street Name  \
# 0                  NaN               NaN                 NaN
# 1       ROCKVILLE PIKE        Government           CENTER DR
# ...

# %% [markdown]
# # Violations

# %%
# %%time
train = pd.read_csv('https://data.montgomerycountymd.gov/resource/4mse-ku6q.csv')
# Out:
# Wall time: 495 ms

# %%
violations = pd.read_csv('https://data.montgomerycountymd.gov/resource/4mse-ku6q.csv')

# %%
violations.head()
# Out:
#                                  seq_id             date_of_stop time_of_stop  \
# 0  7f6afab5-ceb7-4614-8803-7befc44f0d91  2019-10-15T00:00:00.000     22:50:00
# 1  7f6afab5-ceb7-4614-8803-7befc44f0d91  2019-10-15T00:00:00.000     22:50:00
# 2  a584cd65-595c-49ca-95e7-968985e9f90d  2019-10-15T00:00:00.000     22:44:00
# 3  59b5ef04-cfb3-4fbd-ae42-8a445d370506  2019-10-15T00:00:00.000     22:42:00
# 4  dd3522e0-9b77-42ac-9972-039b4313b568  2019-10-15T00:00:00.000     22:40:00
#
#   agency                                        subagency  \
# 0    MCP                           2nd District, Bethesda
# 1    MCP                           2nd District, Bethesda
# 2    MCP  6th District, Gaithersburg / Montgomery Village
# 3    MCP  6th District, Gaithersburg / Montgomery Village
# 4    MCP  6th District, Gaithersburg / Montgomery Village
#
#                                          description  \
# 0  FAILURE OF INDIVIDUAL DRIVING ON HIGHWAY TO DI...
# ...

# %%
violations.shape
# Out:
# (1000, 43)

# %% [markdown]
# **Why is it only importing the first 1,000 rows from the csv?**

# %%
violations.columns.tolist()
# Out:
# ['seq_id',
#  'date_of_stop',
#  'time_of_stop',
#  'agency',
#  'subagency',
#  'description',
#  'location',
#  'latitude',
#  'longitude',
#  'accident',
#  'belts',
#  'personal_injury',
#  'property_damage',
#  'fatal',
#  'commercial_license',
#  'hazmat',
#  'commercial_vehicle',
#  'alcohol',
#  'work_zone',
#  'search_conducted',
#  'search_disposition',
#  'search_outcome',
#  'search_reason',
#  'search_reason_for_stop',
#  'search_type',
#  'search_arrest_reason',
#  'state',
#  'vehicle_type',
#  'year',
#  'make',
#  'model',
#  'color',
#  'violation_type',
#  'charge',
#  'article',
#  'contributed_to_accident',
#  'race',
#  'gender',
#  'driver_city',
#  'driver_state',
#  'dl_state',
#  'arrest_type',
#  'geolocation']

# %%
violations.date_of_stop.value_counts()
# Out:
# 2019-10-15T00:00:00.000    299
# 2019-10-13T00:00:00.000    277
# 2019-10-14T00:00:00.000    228
# 2019-10-12T00:00:00.000    196
# Name: date_of_stop, dtype: int64

# %%
violations.race.value_counts()
# Out:
# WHITE       352
# BLACK       264
# HISPANIC    227
# OTHER        99
# ASIAN        58
# Name: race, dtype: int64

# %%
violations.arrest_type.value_counts()
# Out:
# A - Marked Patrol                         872
# B - Unmarked Patrol                        39
# Q - Marked Laser                           38
# S - License Plate Recognition              18
# O - Foot Patrol                            13
# R - Unmarked Laser                          6
# H - Unmarked Moving Radar (Stationary)      4
# E - Marked Stationary Radar                 3
# M - Marked (Off-Duty)                       3
# L - Motorcycle                              2
# J - Unmarked Moving Radar (Moving)          1
# D - Unmarked VASCAR                         1
# Name: arrest_type, dtype: int64

# %%
violations.description.value_counts().head(10)
# Out:
# DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC CONTROL DEVICE INSTRUCTIONS                          109
# FAILURE TO DISPLAY REGISTRATION CARD UPON DEMAND BY POLICE OFFICER                                   47
# DISPLAYING EXPIRED REGISTRATION PLATE ISSUED BY ANY STATE                                            36
# FAILURE OF INDIVIDUAL DRIVING ON HIGHWAY TO DISPLAY LICENSE TO UNIFORMED POLICE ON DEMAND            29
# DRIVING VEHICLE ON HIGHWAY WITHOUT CURRENT REGISTRATION PLATES AND VALIDATION TABS                   26
# DRIVING VEH. ON HWY. W/O REQUIRED MINIMUM EQUIPMENT                                                  26
# NEGLIGENT DRIVING VEHICLE IN CARELESS AND IMPRUDENT MANNER ENDANGERING PROPERTY, LIFE AND PERSON     23
# DRIVING VEH. W/O ADEQUATE REAR REG. PLATE ILLUMINATION                                               22
# EXCEEDING THE POSTED SPEED LIMIT OF 30 MPH                                                           22
# ...

# %%
reckless = violations.loc[violations['description'] == 'NEGLIGENT DRIVING VEHICLE IN CARELESS AND IMPRUDENT MANNER ENDANGERING PROPERTY, LIFE AND PERSON']

# %%
reckless.
# Out:
#                                    seq_id             date_of_stop  \
# 86   9f5c8837-b2eb-4c8b-a3f7-75917702aa35  2019-10-15T00:00:00.000
# 159  a096a368-02fe-412b-bf2c-90d735d673b4  2019-10-15T00:00:00.000
# 207  6ada70b2-8d87-4d19-a749-4e45dbfbde4d  2019-10-15T00:00:00.000
# 232  f73370c8-84cb-4b2a-bdb6-2c1283a47ab7  2019-10-15T00:00:00.000
# 274  c3a9d2aa-ebe5-4e6a-843f-93da13563aaa  2019-10-15T00:00:00.000
#
#     time_of_stop agency                    subagency  \
# 86      18:15:00    MCP       2nd District, Bethesda
# 159     12:52:00    MCP       2nd District, Bethesda
# 207     10:01:00    MCP     5th District, Germantown
# 232     07:08:00    MCP      1st District, Rockville
# 274     00:53:00    MCP  3rd District, Silver Spring
#
#                                            description  \
# 86   NEGLIGENT DRIVING VEHICLE IN CARELESS AND IMPR...
# 159  NEGLIGENT DRIVING VEHICLE IN CARELESS AND IMPR...
# 207  NEGLIGENT DRIVING VEHICLE IN CARELESS AND IMPR...
# ...

# %% [markdown]
# # Data Compared

# %% [markdown]
# ### Our Data
# - Incidents
# - Drivers
# - Non-Motors

# %% [markdown]
# ### Data Shape

# %%
print(f"Incidents Dataset: {incidents.shape[0]} x {incidents.shape[-1]}")
print(f"Drivers Dataset: {drivers.shape[0]} x {drivers.shape[-1]}")
print(f"Non-Motorists Dataset: {non_motorists.shape[0]} x {non_motorists.shape[-1]}")
# Out:
# Incidents Dataset: 56156 x 44
# Drivers Dataset: 100148 x 43
# Non-Motorists Dataset: 3156 x 32

# %%
incidents.columns.tolist()
# Out:
# ['Report Number',
#  'Local Case Number',
#  'Agency Name',
#  'ACRS Report Type',
#  'Crash Date/Time',
#  'Hit/Run',
#  'Route Type',
#  'Mile Point',
#  'Mile Point Direction',
#  'Lane Direction',
#  'Lane Number',
#  'Lane Type',
#  'Number of Lanes',
#  'Direction',
#  'Distance',
#  'Distance Unit',
#  'Road Grade',
#  'NonTraffic',
#  'Road Name',
#  'Cross-Street Type',
#  'Cross-Street Name',
#  'Off-Road Description',
#  'Municipality',
#  'Related Non-Motorist',
#  'At Fault',
#  'Collision Type',
#  'Weather',
#  'Surface Condition',
#  'Light',
#  'Traffic Control',
#  'Driver Substance Abuse',
#  'Non-Motorist Substance Abuse',
#  'First Harmful Event',
#  'Second Harmful Event',
#  'Fixed Oject Struck',
#  'Junction',
#  'Intersection Type',
#  'Intersection Area',
#  'Road Alignment',
#  'Road Condition',
#  'Road Division',
#  'Latitude',
#  'Longitude',
#  'Location']

# %%
drivers.columns.tolist()
# Out:
# ['Report Number',
#  'Local Case Number',
#  'Agency Name',
#  'ACRS Report Type',
#  'Crash Date/Time',
#  'Route Type',
#  'Road Name',
#  'Cross-Street Type',
#  'Cross-Street Name',
#  'Off-Road Description',
#  'Municipality',
#  'Related Non-Motorist',
#  'Collision Type',
#  'Weather',
#  'Surface Condition',
#  'Light',
#  'Traffic Control',
#  'Driver Substance Abuse',
#  'Non-Motorist Substance Abuse',
#  'Person ID',
#  'Driver At Fault',
#  'Injury Severity',
#  'Circumstance',
#  'Driver Distracted By',
#  'Drivers License State',
#  'Vehicle ID',
#  'Vehicle Damage Extent',
#  'Vehicle First Impact Location',
#  'Vehicle Second Impact Location',
#  'Vehicle Body Type',
#  'Vehicle Movement',
#  'Vehicle Continuing Dir',
#  'Vehicle Going Dir',
#  'Speed Limit',
#  'Driverless Vehicle',
#  'Parked Vehicle',
#  'Vehicle Year',
#  'Vehicle Make',
#  'Vehicle Model',
#  'Equipment Problems',
#  'Latitude',
#  'Longitude',
#  'Location']

# %%
non_motorists.columns.tolist()
# Out:
# ['Report Number',
#  'Local Case Number',
#  'Agency Name',
#  'ACRS Report Type',
#  'Crash Date/Time',
#  'Route Type',
#  'Road Name',
#  'Cross-Street Type',
#  'Cross-Street Name',
#  'Off-Road Description',
#  'Municipality',
#  'Related Non-Motorist',
#  'Collision Type',
#  'Weather',
#  'Surface Condition',
#  'Light',
#  'Traffic Control',
#  'Driver Substance Abuse',
#  'Non-Motorist Substance Abuse',
#  'Person ID',
#  'Pedestrian Type',
#  'Pedestrian Movement',
#  'Pedestrian Actions',
#  'Pedestrian Location',
#  'Pedestrian Obeyed Traffic Signal',
#  'Pedestrian Visibility',
#  'At Fault',
#  'Injury Severity',
#  'Safety Equipment',
#  'Latitude',
#  'Longitude',
#  'Location']

# %%
plt.figure(figsize = (10, 6))
incidents['Surface Condition'].value_counts().plot.bar()

# %%
incidents['Driver Substance Abuse'].value_counts()
# Out:
# NONE DETECTED                                     35519
# NONE DETECTED, UNKNOWN                             2770
# UNKNOWN                                            2681
# N/A, NONE DETECTED                                 1819
# ALCOHOL PRESENT                                    1194
# ALCOHOL PRESENT, NONE DETECTED                      841
# N/A, UNKNOWN                                        667
# ALCOHOL CONTRIBUTED                                 496
# ALCOHOL CONTRIBUTED, NONE DETECTED                  263
# ALCOHOL PRESENT, N/A                                254
# ALCOHOL CONTRIBUTED, N/A                             91
# ILLEGAL DRUG PRESENT                                 79
# ILLEGAL DRUG PRESENT, NONE DETECTED                  62
# MEDICATION PRESENT                                   33
# ILLEGAL DRUG PRESENT, N/A                            28
# MEDICATION PRESENT, NONE DETECTED                    28
# COMBINED SUBSTANCE PRESENT                           23
# ...

# %%
plt.figure(figsize = (10, 6))
incidents['Driver Substance Abuse'].value_counts().head(10).plot.bar()

# %%
plt.figure(figsize = (10, 6))
incidents['Hit/Run'].value_counts().plot.bar()

# %%
print("Type of Weather during Collision")
print("_________________________________\n")
print('Incidents')
print(incidents['Weather'].value_counts().head())
print("_________________________________\n")
print("Drivers")
print(drivers['Weather'].value_counts().head())
print("_________________________________\n")
print("Non-Motorists")
print(non_motorists['Weather'].value_counts().head())
# Out:
# Type of Weather during Collision
# _________________________________
#
# Incidents
# CLEAR      36948
# RAINING     6856
# CLOUDY      5860
# SNOW         675
# UNKNOWN      347
# Name: Weather, dtype: int64
# _________________________________
#
# Drivers
# CLEAR      66788
# RAINING    12196
# CLOUDY     10607
# SNOW        1118
# UNKNOWN      368
# Name: Weather, dtype: int64
# _________________________________
#
# Non-Motorists
# CLEAR      2115
# RAINING     345
# CLOUDY      317
# SNOW         26
# UNKNOWN      17
# Name: Weather, dtype: int64

# %%
incidents['At Fault'].value_counts().plot.bar()

# %%
non_motorists['Safety Equipment'].value_counts()
# Out:
# NONE                   1516
# MC/BIKE HELMET          333
# REFLECTIVE CLOTHING      56
# UNKNOWN                  52
# OTHER                    18
# LIGHTING                  4
# Name: Safety Equipment, dtype: int64

# %%
data = pd.read_csv('data/Traffic_Violations.csv', low_memory = False)

# %%
data.head()
# Out:
#                                   SeqID Date Of Stop Time Of Stop Agency  \
# 0  7f6afab5-ceb7-4614-8803-7befc44f0d91   10/15/2019     22:50:00    MCP
# 1  7f6afab5-ceb7-4614-8803-7befc44f0d91   10/15/2019     22:50:00    MCP
# 2  a584cd65-595c-49ca-95e7-968985e9f90d   10/15/2019     22:44:00    MCP
# 3  59b5ef04-cfb3-4fbd-ae42-8a445d370506   10/15/2019     22:42:00    MCP
# 4  dd3522e0-9b77-42ac-9972-039b4313b568   10/15/2019     22:40:00    MCP
#
#                                          SubAgency  \
# 0                           2nd District, Bethesda
# 1                           2nd District, Bethesda
# 2  6th District, Gaithersburg / Montgomery Village
# 3  6th District, Gaithersburg / Montgomery Village
# 4  6th District, Gaithersburg / Montgomery Village
#
#                                          Description  \
# 0  FAILURE OF INDIVIDUAL DRIVING ON HIGHWAY TO DI...
# 1  DISPLAYING EXPIRED REGISTRATION PLATE ISSUED B...
# ...

# %%
data['Date Of Stop'].value_counts()
# Out:
# 03/17/2015    1281
# 04/10/2018    1277
# 05/20/2014    1222
# 03/05/2019    1186
# 04/18/2018    1185
# 11/24/2015    1169
# 01/25/2017    1167
# 12/08/2015    1150
# 03/08/2016    1141
# 02/11/2015    1135
# 05/06/2014    1128
# 03/07/2016    1127
# 02/21/2017    1110
# 10/20/2015    1101
# 03/09/2016    1099
# 01/20/2015    1098
# 03/12/2019    1089
# 04/09/2019    1087
# 05/14/2014    1087
# 02/21/2018    1087
# 11/25/2014    1083
# 02/17/2016    1082
# 08/28/2018    1069
# 05/28/2014    1061
# 06/09/2015    1055
# 04/08/2014    1051
# 01/23/2018    1050
# 01/16/2015    1050
# 04/12/2016    1049
# 05/30/2014    1045
#               ...
# 08/05/2012     185
# 01/01/2012     181
# 01/28/2012     178
# 01/22/2012     176
# 03/14/2017     176
# 06/23/2013     175
# 02/20/2019     172
# 10/30/2012     171
# 02/11/2012     168
# 12/24/2012     166
# 02/15/2015     163
# 02/05/2012     149
# 01/04/2018     146
# 07/21/2012     138
# 12/25/2013     136
# 01/21/2012     130
# ...
