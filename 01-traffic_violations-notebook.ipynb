# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt 
plt.rc("font", size=14)
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)

# %%
data = pd.read_csv('data/Traffic_Violations (2).csv', low_memory = False)

# %%
data.head()
# Out:
#                                   SeqID Date Of Stop Time Of Stop Agency  \
# 0  02ccadf1-7ebd-48d8-a793-913e3198f52a   07/30/2019     22:15:00    MCP
# 1  3b060228-d664-4480-9314-6188ee8ac891   07/07/2019     22:54:00    MCP
# 2  d4dd55c0-adb0-434e-b5d9-d8346b0a4080   07/10/2019     16:00:00    MCP
# 3  abd509c6-edb3-4818-b90a-477cf92755e6   08/15/2019     22:42:00    MCP
# 4  021d5a2d-7989-4b52-a983-7f6e462fc123   04/15/2019     05:49:00    MCP
#
#                   SubAgency  \
# 0    2nd District, Bethesda
# 1     4th District, Wheaton
# 2   1st District, Rockville
# 3    2nd District, Bethesda
# 4  5th District, Germantown
#
#                                          Description  \
# 0         EXCEEDING THE POSTED SPEED LIMIT OF 35 MPH
# 1                       FAILURE TO STOP AT STOP SIGN
# 2                              HEADLIGHT INOPERATIVE
# 3  DRIVING VEH. W/O ADEQUATE REAR REG. PLATE ILLU...
# 4                  DRIVER CHANGING LANES WHEN UNSAFE
#
#                        Location   Latitude  Longitude Accident  ...  \
# 0    RIVER RD/ROYAL DOMINION DR  38.990102 -77.151645       No  ...
# 1     ENNALLS AVE @ GEORGIA AVE  39.040360 -77.051137       No  ...
# 2          SHADY GROVE @ TUPELO   0.000000   0.000000       No  ...
# 3        355 AT JONES BRIDGE RD  38.997645 -77.096600       No  ...
# 4  GERMANTOWN AT SHAKESPEARE RD   0.000000   0.000000       No  ...
#
#       Charge                 Article Contributed To Accident      Race Gender  \
# 0   21-801.1  Transportation Article                   False     ASIAN      F
# 1  21-707(a)  Transportation Article                   False  HISPANIC      M
# 2   11-393.9          Maryland Rules                   False  HISPANIC      M
# 3  22-204(f)  Transportation Article                   False     WHITE      F
# 4  21-309(b)  Transportation Article                   False     BLACK      F
#
#           Driver City Driver State DL State        Arrest Type  \
# 0             FAIRFAX           VA       VA   Q - Marked Laser
# 1       SILVER SPRING           MD       MD  A - Marked Patrol
# 2          ALEXANDRIA           VA       VA  A - Marked Patrol
# 3             POTOMAC           MD       MD  A - Marked Patrol
# 4  MONTGOMERY VILLAGE           MD       MD  A - Marked Patrol
#
#                       Geolocation
# 0  (38.9901016666667, -77.151645)
# 1   (39.04036, -77.0511366666667)
# 2                      (0.0, 0.0)
# 3           (38.997645, -77.0966)
# 4                      (0.0, 0.0)
#
# [5 rows x 43 columns]

# %%
data = data.rename(columns = {'Search Conducted' : 'Search'})

# %%
data.columns.to_list()
# Out:
# ['SeqID',
#  'Date Of Stop',
#  'Time Of Stop',
#  'Agency',
#  'SubAgency',
#  'Description',
#  'Location',
#  'Latitude',
#  'Longitude',
#  'Accident',
#  'Belts',
#  'Personal Injury',
#  'Property Damage',
#  'Fatal',
#  'Commercial License',
#  'HAZMAT',
#  'Commercial Vehicle',
#  'Alcohol',
#  'Work Zone',
#  'Search',
#  'Search Disposition',
#  'Search Outcome',
#  'Search Reason',
#  'Search Reason For Stop',
#  'Search Type',
#  'Search Arrest Reason',
#  'State',
#  'VehicleType',
#  'Year',
#  'Make',
#  'Model',
#  'Color',
#  'Violation Type',
#  'Charge',
#  'Article',
#  'Contributed To Accident',
#  'Race',
#  'Gender',
#  'Driver City',
#  'Driver State',
#  'DL State',
#  'Arrest Type',
#  'Geolocation']

# %%
data.groupby(['Race', 'Gender']).Search.value_counts()
# Out:
# Race             Gender  Search
# ASIAN            F       No         21312
#                          Yes          369
#                  M       No         33897
#                          Yes         1580
#                  U       No             5
# BLACK            F       No        103038
#                          Yes         4430
#                  M       No        198995
#                          Yes        23666
#                  U       No            12
#                          Yes            4
# HISPANIC         F       No         48144
#                          Yes         2098
#                  M       No        158100
#                          Yes        17502
#                  U       No            20
# NATIVE AMERICAN  F       No           723
#                          Yes           25
#                  M       No          1472
#                          Yes           75
# OTHER            F       No         16716
#                          Yes          325
#                  M       No         34740
#                          Yes         1654
#                  U       No           570
# WHITE            F       No        114816
#                          Yes         4572
#                  M       No        192891
#                          Yes        13824
#                  U       No             5
# Name: Search, dtype: int64

# %%
data2 = data.loc[data['Race'] == 'BLACK']

# %%
data3 = data.loc[data['Race'] == 'WHITE']

# %%
frames = [data2, data3]
result = pd.concat(frames)

# %%
result.Race.value_counts()
# Out:
# WHITE    566346
# BLACK    509102
# Name: Race, dtype: int64

# %%
result.groupby('Race').Search.value_counts()
# Out:
# Race   Search
# BLACK  No        302045
#        Yes        28100
# WHITE  No        307712
#        Yes        18396
# Name: Search, dtype: int64

# %%
data['Violation Type'].value_counts()
# Out:
# Warning     805909
# Citation    721551
# ESERO        76948
# SERO           899
# Name: Violation Type, dtype: int64

# %%
data.groupby('Race')['Charge'].value_counts()
# Out:
# Race   Charge
# ASIAN  21-801.1         14440
#        21-201(a1)        8936
#        13-409(b)         5357
#        21-707(a)         4893
#        21-1124.2(d2)     2428
#        13-411(f)         2297
#        64*               2170
#        21-801(a)         1907
#        13-401(h)         1833
#        22-201.1          1740
#        21-309(b)         1734
#        16-112(c)         1559
#        21-202(h1)        1553
#        21-204(b)         1471
#        13-411(d)         1470
#        22-412.3(b)       1409
#        21-901.1(b)       1336
#        21-801(b)         1215
#        13-411(a)         1087
#        22-226(a)         1065
#        21-204(d)         1041
#        22-204(f)         1023
#        55*                990
#        21-301(a)          882
#        21-405(e1)         875
#        16-116(a)          870
#        21-202(i1)         856
#        21-402(a)          843
#        16-303(c)          808
#        16-303(h)          788
#                         ...
# WHITE  22-104               1
#        22-221(j)            1
#        22-221(l23)          1
#        22-228(a)            1
#        22-228(d)            1
#        22-301(c)            1
#        22-301(i)            1
#        22-301(k)            1
#        22-303               1
#        22-401(a)            1
#        22-405(d)            1
#        22-405.1(c)          1
#        22-406(c)            1
#        22-407(a)            1
#        22-408(a)            1
#        22-408(c)            1
#        22-412.4             1
#        22-414.1             1
#        23-109(b)            1
#        23-109(k)            1
#        24-104               1
#        24-107(b2)           1
#        24-111.1(b)          1
#        24-203               1
#        25-111(g)            1
#        25-112(b3)           1
#        25-202(a2)           1
#        7-705(b1)            1
#        7-705(b5)            1
#        8-409(e)             1
# Name: Charge, Length: 4090, dtype: int64

# %%
data.groupby('Race')['Arrest Type'].value_counts()
# Out:
# Race   Arrest Type
# ASIAN  A - Marked Patrol                          76664
#        Q - Marked Laser                           10019
#        B - Unmarked Patrol                         2562
#        L - Motorcycle                               882
#        O - Foot Patrol                              817
#        E - Marked Stationary Radar                  795
#        G - Marked Moving Radar (Stationary)         593
#        S - License Plate Recognition                450
#        R - Unmarked Laser                           380
#        M - Marked (Off-Duty)                        173
#        I - Marked Moving Radar (Moving)             119
#        H - Unmarked Moving Radar (Stationary)        70
#        F - Unmarked Stationary Radar                 50
#        J - Unmarked Moving Radar (Moving)            44
#        C - Marked VASCAR                             41
#        P - Mounted Patrol                            24
#        D - Unmarked VASCAR                           23
#        N - Unmarked (Off-Duty)                        7
#        K - Aircraft Assist                            1
# BLACK  A - Marked Patrol                         435264
#        Q - Marked Laser                           36701
#        B - Unmarked Patrol                        15587
#        S - License Plate Recognition               6313
#        O - Foot Patrol                             3621
#        L - Motorcycle                              3568
#        E - Marked Stationary Radar                 2487
#        G - Marked Moving Radar (Stationary)        1861
#        R - Unmarked Laser                          1399
#        M - Marked (Off-Duty)                        717
#        I - Marked Moving Radar (Moving)             525
#                                                   ...
# OTHER  G - Marked Moving Radar (Stationary)         488
#        M - Marked (Off-Duty)                        134
#        H - Unmarked Moving Radar (Stationary)       109
#        I - Marked Moving Radar (Moving)             101
#        J - Unmarked Moving Radar (Moving)            87
#        F - Unmarked Stationary Radar                 30
#        P - Mounted Patrol                            21
#        D - Unmarked VASCAR                           12
#        C - Marked VASCAR                              9
#        N - Unmarked (Off-Duty)                        7
#        K - Aircraft Assist                            1
# WHITE  A - Marked Patrol                         441456
#        Q - Marked Laser                           68119
#        B - Unmarked Patrol                        20820
#        O - Foot Patrol                             6685
#        L - Motorcycle                              6236
#        S - License Plate Recognition               5213
#        E - Marked Stationary Radar                 5029
#        G - Marked Moving Radar (Stationary)        4790
#        R - Unmarked Laser                          3260
#        I - Marked Moving Radar (Moving)            1598
#        M - Marked (Off-Duty)                       1016
#        H - Unmarked Moving Radar (Stationary)       685
#        F - Unmarked Stationary Radar                408
#        J - Unmarked Moving Radar (Moving)           394
#        C - Marked VASCAR                            175
#        P - Mounted Patrol                           171
#        D - Unmarked VASCAR                          156
#        N - Unmarked (Off-Duty)                       99
#        K - Aircraft Assist                           36
# Name: Arrest Type, Length: 110, dtype: int64

# %%
data.shape
# Out:
# (1605307, 49)

# %%
data.groupby('Race').Accident.value_counts()
# Out:
# Race             Accident
# ASIAN            No           91418
#                  Yes           2296
# BLACK            No          499509
#                  Yes           9593
# HISPANIC         No          333829
#                  Yes          10063
# NATIVE AMERICAN  No            3140
#                  Yes             93
# OTHER            No           87011
#                  Yes           2009
# WHITE            No          551746
#                  Yes          14600
# Name: Accident, dtype: int64

# %%
print(data.Race.value_counts())
print(data.Race.value_counts(normalize = True))
# Out:
# WHITE              566346
# BLACK              509102
# HISPANIC           343892
# ASIAN               93714
# OTHER               89020
# NATIVE AMERICAN      3233
# Name: Race, dtype: int64
# WHITE              0.352796
# BLACK              0.317137
# HISPANIC           0.214222
# ASIAN              0.058378
# OTHER              0.055454
# NATIVE AMERICAN    0.002014
# Name: Race, dtype: float64

# %%
data.groupby('Race')['Search Outcome'].value_counts(normalize = True).plot.bar(stacked= True)

# %%
df_normalized.plot.bar()

# %%
plt.figure(figsize = (16, 10))
plt.title('Traffic Violations per Race')
plt.xlabel('Race', size = 20)
plt.ylabel('Values', size = 20)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.xticks(rotation=45)

data.Race.value_counts(normalize = True).plot.bar()

# %%
data.Search.unique()
# Out:
# array([nan, 'No', 'Yes'], dtype=object)

# %%
data.Search.value_counts()
# Out:
# No     925456
# Yes     70124
# Name: Search, dtype: int64

# %%
data.groupby('Race').Search.value_counts()
# Out:
# Race             Search
# ASIAN            No         55214
#                  Yes         1949
# BLACK            No        302045
#                  Yes        28100
# HISPANIC         No        206264
#                  Yes        19600
# NATIVE AMERICAN  No          2195
#                  Yes          100
# OTHER            No         52026
#                  Yes         1979
# WHITE            No        307712
#                  Yes        18396
# Name: Search, dtype: int64

# %%
data.groupby('Race')['Search Outcome'].value_counts()
# Out:
# Race             Search Outcome
# ASIAN            Warning                32836
#                  Citation               19720
#                  SERO                    2273
#                  Arrest                  1388
# BLACK            Warning               154146
#                  Citation              142530
#                  Arrest                 17643
#                  SERO                    9713
# HISPANIC         Citation              107657
#                  Warning                90012
#                  Arrest                 15199
#                  SERO                    7863
#                  Recovered Evidence         3
# NATIVE AMERICAN  Warning                 1162
#                  Citation                 878
#                  SERO                     104
#                  Arrest                    69
# OTHER            Warning                30808
#                  Citation               19475
#                  SERO                    1676
#                  Arrest                  1263
# WHITE            Warning               170207
#                  Citation              127039
#                  Arrest                 12953
#                  SERO                    9796
# Name: Search Outcome, dtype: int64

# %% [markdown]
# ## The numbers don't add up.  There's a much higher Search Outcome rate than there are searches conducted
# - make a new pandas df that filters out "Search Conducted == Yes" data

# %%
dataSearch = data.loc[data['Search'] == 'Yes']

# %%
dataSearch.groupby('Race')['Search Outcome'].value_counts()
# Out:
# Race             Search Outcome
# ASIAN            Arrest                 1368
#                  Citation                404
#                  Warning                 160
#                  SERO                     17
# BLACK            Arrest                17471
#                  Citation               7563
#                  Warning                2939
#                  SERO                    127
# HISPANIC         Arrest                15027
#                  Citation               3454
#                  Warning                1046
#                  SERO                     70
#                  Recovered Evidence        3
# NATIVE AMERICAN  Arrest                   69
#                  Warning                  18
#                  Citation                 13
# OTHER            Arrest                 1241
#                  Citation                467
#                  Warning                 263
#                  SERO                      8
# WHITE            Arrest                12752
#                  Citation               3793
#                  Warning                1752
#                  SERO                     99
# Name: Search Outcome, dtype: int64

# %%
dataSearch.groupby('Race').Search.value_counts()
# Out:
# Race             Search
# ASIAN            Yes        1949
# BLACK            Yes       28100
# HISPANIC         Yes       19600
# NATIVE AMERICAN  Yes         100
# OTHER            Yes        1979
# WHITE            Yes       18396
# Name: Search, dtype: int64

# %% [markdown]
# **566,346 white people were pulled over
# 509,102 black people where pulled over**

# %% [markdown]
# Population estimates for Montgomery County as of 2018 is 1,052,567, according to the U.S Census Bureau.
# White people account for 60.2% percent of the population in Moco, Black people account for 19.9% of the population in Moco.
#
# This means white people account for 633,645 persons and black pepople accout 209,461 persons.

# %% [markdown]
# https://www.census.gov/quickfacts/fact/table/montgomerycountymaryland/RHI125218#RHI125218

# %% [markdown]
# #### This means while white people make up 60% percent of the montgomery county population, they were only pulled over 35% of the time.
# #### And while black people only make up 19.9% of the population, they were pulled over 31% of the time

# %% [markdown]
# Normalizing the data:

# %%
data.Search.isna().value_counts()
# Out:
# False    995580
# True     609727
# Name: Search, dtype: int64

# %% [markdown]
# **We are missing 609,727 records if the individual was searched over or not**

# %%
data.groupby('Race').Search.value_counts(normalize = True)
# Out:
# Race             Search
# ASIAN            No        0.965905
#                  Yes       0.034095
# BLACK            No        0.914886
#                  Yes       0.085114
# HISPANIC         No        0.913222
#                  Yes       0.086778
# NATIVE AMERICAN  No        0.956427
#                  Yes       0.043573
# OTHER            No        0.963355
#                  Yes       0.036645
# WHITE            No        0.943589
#                  Yes       0.056411
# Name: Search, dtype: float64

# %%
plt.figure(figsize = (16, 8))
data.groupby('Race').Search.value_counts()
# Out:
# Race             Search
# ASIAN            No         55214
#                  Yes         1949
# BLACK            No        302045
#                  Yes        28100
# HISPANIC         No        206264
#                  Yes        19600
# NATIVE AMERICAN  No          2195
#                  Yes          100
# OTHER            No         52026
#                  Yes         1979
# WHITE            No        307712
#                  Yes        18396
# Name: Search, dtype: int64

# %%
data.Race.value_counts()
# Out:
# WHITE              566346
# BLACK              509102
# HISPANIC           343892
# ASIAN               93714
# OTHER               89020
# NATIVE AMERICAN      3233
# Name: Race, dtype: int64

# %% [markdown]
# # Time Series

# %%
import seaborn as sns

# %%
sns.barplot(x=df.reputation.value_counts().index, y=df.reputation.value_counts())

# %%
from datetime import datetime

# %%
data = data.rename(columns = {'Date Of Stop' : 'Date'})

# %%
# import datetime librarby to convert objects to datetimes
# from datetime import datetime

# changes 'time_stamp' to datetime
data['Date'] = pd.to_datetime(data['Date'])

# %%
# creating new empty columns to fill with time_stamp information
data['full_date'] = ''
data['year'] = ''
data['month'] = ''
data['day'] = ''
data['season'] = ''
data['workday'] = ''

# %%
data.full_date = data.Date.dt.date
data.year = data.Date.dt.year
data.month = data.Date.dt.month
data.day = data.Date.dt.day
data.workday = data.Date.dt.dayofweek

# %%
data.full_date.value_counts().head()
# Out:
# 2015-03-17    1281
# 2018-04-10    1277
# 2014-05-20    1222
# 2019-03-05    1186
# 2018-04-18    1185
# Name: full_date, dtype: int64

# %%
data.year.value_counts()
# Out:
# 2015    235370
# 2014    223784
# 2016    219758
# 2018    218287
# 2017    199170
# 2013    190519
# 2019    167044
# 2012    151375
# Name: year, dtype: int64

# %%
import pandas as pd

value_counts = data['year'].value_counts(dropna=True, sort=True)

# solution here
data_val_counts_year = pd.DataFrame(value_counts)
data_value_counts_year = data_val_counts_year.reset_index()
data_value_counts_year.columns = ['unique_values', 'counts'] # change column names

# sort the values by year to time series line doesn't get messed up
data_value_counts_year = data_value_counts_year.sort_values(by=['unique_values'])

# %%
data_value_counts_year.head()
# Out:
#    unique_values  counts
# 7           2012  151375
# 5           2013  190519
# 1           2014  223784
# 0           2015  235370
# 2           2016  219758

# %%
# Draw Plot
def plot_df(data, x, y, title="", xlabel='Date', ylabel='Value', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

plot_df(data_value_counts_year, x=data_value_counts_year.unique_values, y=data_value_counts_year.counts, title='Traffic Violations in Montgomery County')

# %% [markdown]
# # Time series per Month

# %%
import pandas as pd

value_counts = data['month'].value_counts(dropna=True, sort=True)

# solution here
data_val_counts_month = pd.DataFrame(value_counts)
data_value_counts_month = data_val_counts_month.reset_index()
data_value_counts_month.columns = ['unique_values', 'counts'] # change column names

# %%
data_value_counts_month = data_value_counts_month.sort_values(by=['unique_values'])
data_value_counts_month.head()
# Out:
#    unique_values  counts
# 9              1  124622
# 8              2  129901
# 0              3  149692
# 2              4  148417
# 1              5  149081

# %%
# Draw Plot
def plot_df(data_value_counts_month, x, y, title="", xlabel='Date', ylabel='Value', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

plot_df(data_value_counts_month, x=data_value_counts_month.unique_values, y=data_value_counts_month.counts, title='Traffic Violations in Montgomery County')

# %% [markdown]
# # Time series for full date

# %%
import pandas as pd

value_counts = data['full_date'].value_counts(dropna=True, sort=True)

# solution here
data_val_counts_full_date = pd.DataFrame(value_counts)
data_value_counts_full_date = data_val_counts_full_date.reset_index()
data_value_counts_full_date.columns = ['unique_values', 'counts'] # change column names

# %%
data_value_counts_full_date = data_value_counts_full_date.sort_values(by=['unique_values'])
data_value_counts_full_date.head()
# Out:
#      unique_values  counts
# 2841    2012-01-01     181
# 2553    2012-01-02     334
# 2563    2012-01-03     330
# 2432    2012-01-04     364
# 1923    2012-01-05     465

# %%
# Draw Plot
def plot_df(data_value_counts_full_date, x, y, title="", xlabel='Date', ylabel='Value', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

plot_df(data_value_counts_full_date, x=data_value_counts_full_date.unique_values, y=data_value_counts_full_date.counts, title='Traffic Violations in Montgomery County')

# %% [markdown]
# # Time series for month and year

# %%
y12 = data.loc[data['year'] == 2012].month.value_counts(sort = False)
y13 = data.loc[data['year'] == 2013].month.value_counts(sort = False)
y14 = data.loc[data['year'] == 2014].month.value_counts(sort = False)
y15 = data.loc[data['year'] == 2015].month.value_counts(sort = False)
y16 = data.loc[data['year'] == 2016].month.value_counts(sort = False)
y17 = data.loc[data['year'] == 2017].month.value_counts(sort = False)
y18 = data.loc[data['year'] == 2018].month.value_counts(sort = False)
y19 = data.loc[data['year'] == 2019].month.value_counts(sort = False)

# %%
y12
# Out:
# 1     10253
# 2     10342
# 3     11624
# 4     13174
# 5     17397
# 6     13075
# 7     11694
# 8     12116
# 9     12069
# 10    13162
# 11    13593
# 12    12876
# Name: month, dtype: int64

# %% [markdown]
# # Time series for Month and Year

# %%
def plot_easy(y12, y13, y14, y15, y16, y17, y18, y19):
    plt.figure(figsize = (20, 8))
    plt.plot(y12, label = '2012', color = 'red')
    plt.plot(y13, label = '2013', color = 'cyan')
    plt.plot(y14, label = '2014', color = 'green')
    plt.plot(y15, label = '2015', color = 'tomato')
    plt.plot(y16, label = '2016', color = 'blue')
    plt.plot(y17, label = '2017', color = 'magenta')
    plt.plot(y18, label = '2018', color = 'orange')
    plt.plot(y19, label = '2019', color = 'black')
    plt.title('Traffic Violations per Month and Year')
    plt.xlabel('Date')
    plt.ylabel('Values')
    plt.legend()
    plt.show()
    
plot_easy(y12, y13, y14, y15, y16, y17, y18, y19)

# %% [markdown]
# **We can see that 2019 numbers drop down randomly, since the data is not complete for the ongoing year**

# %% [markdown]
# # Time series for month and year except 2019

# %%
def plot_easy(y12, y13, y14, y15, y16, y17, y18):
    plt.figure(figsize = (20, 8))
    plt.plot(y12, label = '2012', color = 'red')
    plt.plot(y14, label = '2014', color = 'green')
    plt.plot(y15, label = '2015', color = 'tomato')
    plt.plot(y16, label = '2016', color = 'blue')
    plt.plot(y18, label = '2018', color = 'orange')
    plt.title('Traffic Violations per Month and Year')
    plt.xlabel('Date')
    plt.ylabel('Values')
    plt.legend()
    plt.show()
    
plot_easy(y12, y13, y14, y15, y16, y17, y18)

# %% [markdown]
# # Trafic violations for year 16, 17, 18
# - to compare with accident rates

# %%
def plot_easy(y16, y17, y18):
    plt.figure(figsize = (20, 8))
    plt.plot(y16, label = '2016', color = 'blue')
    plt.plot(y17, label = '2017', color = 'magenta')
    plt.plot(y18, label = '2018', color = 'orange')
    plt.title('Traffic Violations per Month and Year')
    plt.xlabel('Date')
    plt.ylabel('Values')
    plt.legend()
    plt.show()
    
plot_easy(y16, y17, y18)
